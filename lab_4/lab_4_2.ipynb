# %%
import pandas as pd
import numpy as np

import missingno as msno
print("Setup ok")

# file = "household_power_consumption.csv"
file = "cars.data"
# Out:
# Setup ok

# %% [markdown]
# <table>
#   <tr>
#     <th>Variable Name</th>
#     <th>Role</th>
#     <th>Type</th>
#     <th>Description</th>
#     <th>Missing Values</th>
#   </tr>
#   <tr>
#     <td>width</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 60.3 to 72.3</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>length</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 141.1 to 208.1</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>wheel-base</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 86.6 to 120.9</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>engine-location</td>
#     <td>Feature</td>
#     <td>Binary</td>
#     <td>front, rear</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>drive-wheels</td>
#     <td>Feature</td>
#     <td>Categorical</td>
#     <td>4wd, fwd, rwd</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>body-style</td>
#     <td>Feature</td>
#     <td>Categorical</td>
#     <td>hardtop, wagon, sedan, hatchback, convertible</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>num-of-doors</td>
#     <td>Feature</td>
#     <td>Integer</td>
#     <td>four, two</td>
#     <td>yes</td>
#   </tr>
#   <tr>
#     <td>aspiration</td>
#     <td>Feature</td>
#     <td>Binary</td>
#     <td>std, turbo</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>fuel-type</td>
#     <td>Feature</td>
#     <td>Binary</td>
#     <td>diesel, gas</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>make</td>
#     <td>Feature</td>
#     <td>Categorical</td>
#     <td>alfa-romero, audi, bmw, chevrolet, dodge, honda, isuzu,
#     jaguar, mazda, mercedes-benz, mercury, mitsubishi, nissan,
#     peugot, plymouth, porsche, renault, saab, subaru, toyota,
#     volkswagen, volvo</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>normalized-losses</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 65 to 256</td>
#     <td>yes</td>
#   </tr>
#   <tr>
#     <td>price</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 5118 to 45400</td>
#     <td>yes</td>
#   </tr>
#   <tr>
#     <td>highway-mpg</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 16 to 54</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>city-mpg</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 13 to 49</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>peak-rpm</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 4150 to 6600</td>
#     <td>yes</td>
#   </tr>
#   <tr>
#     <td>horsepower</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 48 to 288</td>
#     <td>yes</td>
#   </tr>
#   <tr>
#     <td>compression-ratio</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 7 to 23</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>stroke</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 2.07 to 4.17</td>
#     <td>yes</td>
#   </tr>
#   <tr>
#     <td>bore</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 2.54 to 3.94</td>
#     <td>yes</td>
#   </tr>
#   <tr>
#     <td>fuel-system</td>
#     <td>Feature</td>
#     <td>Categorical</td>
#     <td>1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>engine-size</td>
#     <td>Feature</td>
#     <td>Continuous</td>
#     <td>continuous from 61 to 326</td>
#     <td>no</td>
#   </tr>
#   <tr>
#     <td>num-of-cylinders</td>
#     <td>Feature</td>
#     <td>Integer</td>
#     <td>eight, five, four, six, three, twelve, two</td>
#     <td>no</td>
#   </tr>
#   <tr>
# <p>
# Attribute: Attribute Range
#
#   1. symboling:                -3, -2, -1, 0, 1, 2, 3.
#   2. normalized-losses:        continuous from 65 to 256.
#   3. make:
#                                alfa-romero, audi, bmw, chevrolet, dodge, honda,
#                                isuzu, jaguar, mazda, mercedes-benz, mercury,
#                                mitsubishi, nissan, peugot, plymouth, porsche,
#                                renault, saab, subaru, toyota, volkswagen, volvo
#
#   4. fuel-type:                diesel, gas.
#   5. aspiration:               std, turbo.
#   6. num-of-doors:             four, two.
#   7. body-style:               hardtop, wagon, sedan, hatchback, convertible.
#   8. drive-wheels:             4wd, fwd, rwd.
#   9. engine-location:          front, rear.
#  10. wheel-base:               continuous from 86.6 120.9.
#  11. length:                   continuous from 141.1 to 208.1.
#  12. width:                    continuous from 60.3 to 72.3.
#  13. height:                   continuous from 47.8 to 59.8.
#  14. curb-weight:              continuous from 1488 to 4066.
#  15. engine-type:              dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
#  16. num-of-cylinders:         eight, five, four, six, three, twelve, two.
#  17. engine-size:              continuous from 61 to 326.
#  18. fuel-system:              1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
#  19. bore:                     continuous from 2.54 to 3.94.
#  20. stroke:                   continuous from 2.07 to 4.17.
#  21. compression-ratio:        continuous from 7 to 23.
#  22. horsepower:               continuous from 48 to 288.
#  23. peak-rpm:                 continuous from 4150 to 6600.
#  24. city-mpg:                 continuous from 13 to 49.
#  25. highway-mpg:              continuous from 16 to 54.
#  26. price:                    continuous from 5118 to 45400.
#  </p>

# %% [markdown]
# Створення dataframe з csv файлу

# %%
def create_numpy_arr(file1):
    data = np.genfromtxt(file1, delimiter=',')
    return data

def create_data_frame(file1):
    header = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
    df1 = pd.read_csv(file1, names=header, low_memory=False, na_values="?")
    return df1
# print(create_data_frame(file))
# print(create_data_frame(file).to_numpy()[0])

df = create_data_frame(file)
df_np = create_numpy_arr(file)

# %% [markdown]
# Видалення пустих даних

# %%
# Опрацювання пустих значень
msno.matrix(df)


# rows_with_null = df[df.isnull().any(axis=1)]
# print(rows_with_null)

df = df.dropna(subset=['num-of-doors', 'stroke', 'bore', 'normalized-losses'] )
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# Нормалізація даних

# %%
def normalize_dataset(dataset):
    normalized_dataset = dataset.copy()
    for column in normalized_dataset.columns:
        if normalized_dataset[column].dtype in ['int64', 'float64']:
            # Мін-Макс нормалізація
            min_value = normalized_dataset[column].min()
            max_value = normalized_dataset[column].max()
            normalized_dataset[column] = (normalized_dataset[column] - min_value) / (max_value - min_value)
    return normalized_dataset

df = normalize_dataset(df)

# %%
def plot_histogram(dataset, attribute, num_bins=10):
    # Визначення меж діапазонів для гістограми
    min_value = dataset[attribute].min()
    max_value = dataset[attribute].max()
    bin_width = (max_value - min_value) / num_bins
    bins = [min_value + i * bin_width for i in range(num_bins + 1)]
    
    # Побудова гістограми
    plt.hist(dataset[attribute], bins=bins, edgecolor='black')
    
    # Налаштування відображення графіка
    plt.title(f'Histogram of {attribute}')
    plt.xlabel(attribute)
    plt.ylabel('Frequency')
    plt.grid(True)
    
    # Відображення графіка
    plt.show()


def plot_attribute_relation(dataset, x_attribute, y_attribute,):
    # Побудова графіка
    sns.regplot(data=dataset ,x=x_attribute , y=y_attribute)
    
    # Налаштування відображення графіка
    plt.title(f'{y_attribute} vs {x_attribute}')
    plt.xlabel(x_attribute)
    plt.ylabel(y_attribute)
    plt.grid(True)
    
    # Відображення графіка
    plt.show()

# %%
plot_histogram(df, 'engine-size', num_bins=10)
plot_histogram(df, 'price', num_bins=10)
plot_attribute_relation(df, 'price','engine-size',)

plot_histogram(df, 'highway-mpg', num_bins=16)
plot_histogram(df, 'horsepower', num_bins=16)
plot_attribute_relation(df, 'highway-mpg','horsepower')

# %% [markdown]
# **Кореляція** — це статистичний показник, який повідомляє нам про зв’язок між двома змінними. Він описує, як поводиться одна змінна, якщо є деякі зміни в іншій змінній.
#
# **Коефіцієнт кореляції Пірсона** — це статистичний показник, який кількісно визначає силу та напрямок лінійного зв’язку між двома змінними. Він варіюється від -1 до 1, причому значення, близькі до -1, вказують на сильний негативний лінійний зв'язок, значення, близькі до 1, вказують на сильний позитивний лінійний зв'язок, а 0 вказує на відсутність лінійного зв'язку.
#
# **Коефіцієнт кореляції Спірмена** — це статистичний показник, який оцінює силу та напрямок монотонного зв’язку між двома змінними. Він ранжує дані, а не покладається на їхні фактичні значення, що робить його придатним для ненормально розподілених або порядкових даних. Він коливається від -1 до 1, де значення, близькі до -1 або 1, вказують на сильний монотонний зв'язок, а 0 вказує на відсутність монотонного зв'язку. Кореляція Спірмена є важливою для виявлення та кількісного визначення зв’язків, коли не передбачається лінійних зв’язків або коли мова йде про ранжовані чи порядкові дані

# %%
from scipy.stats import pearsonr, spearmanr

def calculate_correlation(dataset, x_attribute, y_attribute):
    # Витягнення значень атрибутів з датасету
    x_values = dataset[x_attribute]
    y_values = dataset[y_attribute]
    
    # Підрахунок коефіцієнта Пірсона
    pearson_corr, _ = pearsonr(x_values, y_values)
    
    # Підрахунок коефіцієнта Спірсона
    spearman_corr, _ = spearmanr(x_values, y_values)

    print(f"Correlation coefficient: {x_attribute}, {y_attribute}")
    print("\tPearson:", pearson_corr)
    print("\tSpearman:", spearman_corr,'\n')

    return pearson_corr, spearman_corr

calculate_correlation(df, 'engine-size', 'price')
calculate_correlation(df, 'horsepower', 'highway-mpg')

calculate_correlation(df, 'peak-rpm', 'horsepower')
calculate_correlation(df, 'horsepower', 'curb-weight')
# Out:
# Correlation coefficient: engine-size, price
# 	Pearson: 0.8414956026114566
# 	Spearman: 0.8664906588599569
#
# Correlation coefficient: horsepower, highway-mpg
# 	Pearson: -0.8279410511954652
# 	Spearman: -0.8986415940120215
#
# Correlation coefficient: peak-rpm, horsepower
# 	Pearson: 0.07405682424750927
# 	Spearman: 0.07450538804918076
#
# Correlation coefficient: horsepower, curb-weight
# 	Pearson: 0.7900953915415863
# 	Spearman: 0.821370989604657

# %%
from sklearn.preprocessing import OneHotEncoder

def one_hot_encode_categorical(dataset, categorical_columns1):
    
    # Вибір категоріальних ознак з датасету
    categorical_data = dataset[categorical_columns1]

    # Створення екземпляра OneHotEncoder
    encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    onehot_encoded = encoder.fit_transform(categorical_data)


    # Підготовка та навчання кодувальника OneHotEncoder на категоріальних даних
    encoder.fit(categorical_data)
    
    # Проведення One Hot Encoding на категоріальних даних
    encoded_data = encoder.transform(categorical_data)
    
    # Створення імен колонок для закодованих даних
    encoded_columns = encoder.get_feature_names_out(categorical_columns1)
    print(encoded_columns)
    
    # Видалення вихідних категоріальних стовпців
    encoded_df1 = df.drop(columns=categorical_columns1, axis=1)

    # Створення DataFrame з закодованими даними
    encoded_df1.loc[:, encoded_columns] = encoded_data
    

    # Повернення DataFrame з закодованими даними
    return encoded_df1

# Вказівка, які стовпці є категоріальними
categorical_columns = ['fuel-type', 'drive-wheels', 'body-style', 'make', 'aspiration', 
                       'num-of-doors', 'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system']
encoded_df = one_hot_encode_categorical(df, categorical_columns)
# Out:
# ['fuel-type_diesel' 'fuel-type_gas' 'drive-wheels_4wd' 'drive-wheels_fwd'
#  'drive-wheels_rwd' 'body-style_convertible' 'body-style_hardtop'
#  'body-style_hatchback' 'body-style_sedan' 'body-style_wagon' 'make_audi'
#  'make_bmw' 'make_chevrolet' 'make_dodge' 'make_honda' 'make_jaguar'
#  'make_mazda' 'make_mercedes-benz' 'make_mitsubishi' 'make_nissan'
#  'make_peugot' 'make_plymouth' 'make_porsche' 'make_saab' 'make_subaru'
#  'make_toyota' 'make_volkswagen' 'make_volvo' 'aspiration_std'
#  'aspiration_turbo' 'num-of-doors_four' 'num-of-doors_two'
#  'engine-location_front' 'engine-type_dohc' 'engine-type_l'
#  'engine-type_ohc' 'engine-type_ohcf' 'engine-type_ohcv'
#  'num-of-cylinders_eight' 'num-of-cylinders_five' 'num-of-cylinders_four'
#  'num-of-cylinders_six' 'num-of-cylinders_three' 'fuel-system_1bbl'
#  'fuel-system_2bbl' 'fuel-system_idi' 'fuel-system_mfi' 'fuel-system_mpfi'
#  'fuel-system_spdi']

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df_test = encoded_df[['curb-weight', 'engine-size', 'height', 'width', 'length', 'peak-rpm']]

corr = encoded_df[['curb-weight', 'engine-size', 'height', 'width', 'length', 'peak-rpm']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

sns.pairplot(df_test, kind='hist')
plt.title('Pairplot with Regression Lines')
plt.show()


sns.pairplot(df_test, diag_kind='kde')
plt.title('Pairplot with Kernel Density Estimates')
plt.show()

# %% [markdown]
# **Лінійна регресія** — це потужний статистичний метод, який використовується для моделювання зв’язку між залежною змінною та однією або кількома незалежними змінними.
#
# Mean Squared Error (MSE), або середньоквадратична помилка, є метрикою, яка використовується для оцінки якості моделі у задачах регресії. Вона вимірює середнє значення квадратів відхилень між прогнозованими значеннями моделі та справжніми значеннями.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Розділення датасету на дві рівні частини
df_train, df_test = train_test_split(df, test_size=0.5, random_state=42)

# Функція для навчання та оцінки регресійної моделі
def train_and_evaluate_regression_model(feature, target, df_train1, df_test1):

    # Навчання
    x_train = df_train1[feature]
    y_train = df_train1[target]

    # Оцінка
    x_test = df_test1[feature]
    y_test = df_test1[target]
    
    # Ініціалізація та навчання моделі
    model = LinearRegression()

    model.fit(x_train, y_train)
    
    # Передбачення на тестовому наборі
    y_pred = model.predict(x_test)
    
    # Оцінка моделі
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("Mean Squared Error:", mse)
  
    print("Coefficients: \n", model.coef_)
    # Коефіцієнт детермінації: 1 – ідеальний прогноз
    print("Coefficient of determination: %.2f" % r2)

    if len(feature) == 1:
        plt.scatter(x_train, y_train, label='Data')
        plt.plot(x_test, y_pred, color='red', linewidth=2, label='Regression Line')
        plt.xlabel(feature)
        plt.ylabel(target)
        plt.title('Linear Regression Model')
        plt.text(0.02, 0.8, f'MSE: {mse:.5f}', transform=plt.gca().transAxes, fontsize=12)
        plt.text(0.02, 0.7, f'r2: {r2}', transform=plt.gca().transAxes, fontsize=12)
        plt.text(0.02, 0.6, f'cof: {model.coef_[0]:.5f}', transform=plt.gca().transAxes, fontsize=12)
        plt.legend()
        plt.show()

    return model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 from sklearn.metrics import mean_squared_error, r2_score
#       5 # Розділення датасету на дві рівні частини
# ----> 6 df_train, df_test = train_test_split(df, test_size=0.5, random_state=42)
#       8 # Функція для навчання та оцінки регресійної моделі
#       9 def train_and_evaluate_regression_model(feature, target, df_train, df_test):
#      10
#      11     # Навчання
#
# NameError: name 'df' is not defined

# %%
train_and_evaluate_regression_model(['horsepower'], 'price', df_train, df_test)
train_and_evaluate_regression_model(['peak-rpm'], 'price', df_train, df_test)
train_and_evaluate_regression_model(['engine-size','horsepower','highway-mpg', 'curb-weight', 'symboling'], 'price', df_train, df_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model1 = train_and_evaluate_regression_model(['horsepower'], 'price', df_train, df_test)
#       2 model1 = train_and_evaluate_regression_model(['peak-rpm'], 'price', df_train, df_test)
#       3 model1 = train_and_evaluate_regression_model(['engine-size','horsepower','highway-mpg', 'curb-weight', 'symboling'], 'price', df_train, df_test)
#
# NameError: name 'train_and_evaluate_regression_model' is not defined
